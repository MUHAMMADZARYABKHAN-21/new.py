# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.array([
    [0, 50, 100],
    [150, 200, 255],
    [250, 150, 250]
])

plt.imshow(image)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.array([
    [0, 50, 100],
    [150, 200, 255],
    [50, 150, 250]
])

plt.imshow(image,cmap='gray')
plt.imshow(image, cmap="viridis")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.random.rand(20,20)

fig, axes = plt.subplots(1,3, figsize=(12,4))

axes[0].imshow(image, cmap="gray")
axes[0].set_title("Gray")

axes[1].imshow(image, cmap="viridis")
axes[1].set_title("Viridis")

axes[2].imshow(image, cmap="hot")
axes[2].set_title("Hot")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

image = np.random.rand(20,20)

fig, axes = plt.subplots(1,3, figsize=(12,4))

axes[0].imshow(image, cmap="gray")
axes[0].set_title("Gray")

axes[1].imshow(image, cmap="viridis")
axes[1].set_title("Viridis")

axes[2].imshow(image, cmap="hot")
axes[2].set_title("Hot")

plt.show()
image = plt.imread("cat.jpg")

plt.imshow(image)

plt.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 19
#      15 axes[2].imshow(image, cmap="hot")
#      16 axes[2].set_title("Hot")
#      17
#      18 plt.show()
# ---> 19 image = plt.imread("cat.jpg")
#      20
#      21 plt.imshow(image)
#      22
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:2763, in imread(fname, format)
#    2759 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2760 def imread(
#    2761         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2762 ) -> np.ndarray:
# -> 2763     return matplotlib.image.imread(fname, format)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\image.py:1587, in imread(fname, format)
#    1580 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("titanic.csv")

corr = df[["age", "fare", "pclass", "sibsp", "parch"]].corr()

plt.figure(figsize=(6,5))

plt.imshow(corr, cmap="coolwarm")

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Matrix")

plt.show()
