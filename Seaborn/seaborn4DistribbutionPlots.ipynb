# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="sex",
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=False,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=4

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")
plt.figure(figsize=(10,5))

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=3,
    linestyle="--",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=2

)
plt.title("Kernel Density Estimation")
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.histplot(
    data=df,
    x="age",
    kde=True,
)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ****When Should You Use a KDE Plot?
#
# Use a KDE plot when you want to:
#
# Understand the overall shape of your data.
# Compare distributions between groups.
# See where values are concentrated.
# Avoid the blocky appearance of a histogram.
#
# Avoid using KDE when:
#
# Your dataset is very small (the curve may be misleading).
# Your variable is categorical instead of numerical.****

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="fare",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.displot(data=df,x="age")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="sex",
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=False,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=4

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")
plt.figure(figsize=(10,5))

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=3,
    linestyle="--",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=2

)
plt.title("Kernel Density Estimation")
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.histplot(
    data=df,
    x="age",
    kde=True,
)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ****When Should You Use a KDE Plot?
#
# Use a KDE plot when you want to:
#
# Understand the overall shape of your data.
# Compare distributions between groups.
# See where values are concentrated.
# Avoid the blocky appearance of a histogram.
#
# Avoid using KDE when:
#
# Your dataset is very small (the curve may be misleading).
# Your variable is categorical instead of numerical.****

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="fare",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.displot(data=df,
            x="age",
            kind="kde",


            )
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.displot(
    data=df,
    x="age",
    kde=True,
    color="blue",
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.displot(
    data=df,
    x="age",
    kde=True,
    color="blue",
    bins=20
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
# sns.displot(
#     data=df,
#     x="age",
#     kde=True,
#     color="blue",
#     col="sex"
# )
sns.displot(
    data=df,
    x="age",
    color="green",
    col="sex"
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
# sns.displot(
#     data=df,
#     x="age",
#     kde=True,
#     color="blue",
#     col="sex"
# )
sns.displot(
    data=df,
    x="fare",
    color="green",
    col="pclass"
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
# sns.displot(
#     data=df,
#     x="age",
#     kde=True,
#     color="blue",
#     col="sex"
# )
sns.displot(
    data=df,
    x="fare",
    color="green",
   hue="sex"
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
# sns.displot(
#     data=df,
#     x="age",
#     kde=True,
#     color="blue",
#     col="sex"
# )
sns.displot(
    data=df,
    x="fare",
    row="sex",
    col="pclass"
)
plt.title("Fare distribution")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("Titanic1.csv")
sns.displot(
    data=df,
    x="age",
    height=5,
    aspect=1.5
)

# %%
# ============================================
# Seaborn Lesson 3 - Distribution Plots
# histplot(), kdeplot(), displot()
# Dataset: Titanic1.csv
# ============================================

# Import Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("Titanic1.csv")

# Preview Dataset
print(df.head())
print(df.info())

# ============================================
# 1. Basic Histogram
# ============================================

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="age")
plt.title("Histogram of Age")
plt.show()

# ============================================
# 2. Histogram with KDE
# ============================================

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="age", kde=True)
plt.title("Histogram with KDE")
plt.show()

# ============================================
# 3. Histogram with Custom Bins
# ============================================

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="age", bins=20)
plt.title("Histogram with 20 Bins")
plt.show()

# ============================================
# 4. Histogram with Color
# ============================================

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="age", color="green")
plt.title("Green Histogram")
plt.show()

# ============================================
# 5. Histogram by Gender
# ============================================

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="age", hue="sex", kde=True)
plt.title("Age Distribution by Gender")
plt.show()

# ============================================
# 6. KDE Plot
# ============================================

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age")
plt.title("KDE Plot")
plt.show()

# ============================================
# 7. Filled KDE
# ============================================

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age", fill=True)
plt.title("Filled KDE")
plt.show()

# ============================================
# 8. Filled KDE with Green Color
# ============================================

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age", fill=True, color="green")
plt.title("Green Filled KDE")
plt.show()

# ============================================
# 9. KDE by Gender
# ============================================

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age", hue="sex", fill=True)
plt.title("Age Distribution by Gender")
plt.show()

# ============================================
# 10. KDE with Thick Line
# ============================================

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age", linewidth=3)
plt.title("Thick KDE Line")
plt.show()

# ============================================
# 11. KDE with Dashed Line
# ============================================

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age", linestyle="--")
plt.title("Dashed KDE")
plt.show()

# ============================================
# 12. displot - Histogram
# ============================================

sns.displot(data=df, x="age")
plt.show()

# ============================================
# 13. displot - KDE
# ============================================

sns.displot(data=df, x="age", kind="kde")
plt.show()

# ============================================
# 14. displot - Histogram + KDE
# ============================================

sns.displot(data=df, x="age", kde=True)
plt.show()

# ============================================
# 15. displot with Custom Bins
# ============================================

sns.displot(data=df, x="age", bins=20)
plt.show()

# ============================================
# 16. displot with Green Color
# ============================================

sns.displot(data=df, x="age", color="green")
plt.show()

# ============================================
# 17. displot by Gender (Separate Columns)
# ============================================

sns.displot(data=df, x="age", col="sex")
plt.show()

# ============================================
# 18. displot by Passenger Class
# ============================================

sns.displot(data=df, x="fare", col="pclass")
plt.show()

# ============================================
# 19. displot with hue
# ============================================

sns.displot(data=df, x="age", hue="sex", kde=True)
plt.show()

# ============================================
# 20. displot with Row and Column
# ============================================

sns.displot(
    data=df,
    x="fare",
    row="sex",
    col="pclass"
)
plt.show()

# ============================================
# 21. displot with Height and Aspect
# ============================================

sns.displot(
    data=df,
    x="age",
    height=5,
    aspect=1.5
)
plt.show()

print("All Distribution Plot Examples Completed Successfully!")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.displot(
    data=df,
    x="age",
    kde=True
)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
    hue="sex",
    multiple="stack"
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
    hue="sex",
    multiple="layer"
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
    hue="sex",
    multiple="dodge"
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
    hue="sex",
    multiple="stack"
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
    hue="sex",
    multiple="stack"
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
   col="sex"
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="age",
   col="pclass",
)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(
    data=df,
    x="fare",
   col="pclass",
    hue="sex",
    kde=True

)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.ecdfplot(
    data=df,
    x="age",

)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.ecdfplot(
    data=df,
    x="age",
    color="red"

)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.ecdfplot(
    data=df,
    x="age",
    hue="sex"
)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.ecdfplot(
    data=df,
    x="pclass",
)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.ecdfplot(
    data=df,
    x="fare",
    hue="pclass"
)

plt.title("ECDF of Titanic Fares")
plt.xlabel("Fare")
plt.ylabel("Cumulative Probability")

plt.show()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.scatterplot(
    data=df,
    x="age",
    y="fare"
)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.scatterplot(
    data=df,
    x="age",
    y="fare",
    color="purple"
)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.scatterplot(
    data=df,
    x="age",
    y="fare",

    color="purple",
    size ="fare"
)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.scatterplot(
    data=df,
    x="age",
    y="fare",
    color="purple",
    style = "survived"
)


plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="age",
    y="fare",
    hue="sex",
    style="survived",
    size="pclass",
    palette="Set2"
)

plt.title("Titanic Passenger Analysis")

plt.show()

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

# 1: Age vs Fare
sns.scatterplot(data=df, x="age", y="fare")

# 2: Age vs Fare, colored by sex
sns.scatterplot(data=df, x="age", y="fare", hue="sex")

# 3: Fare vs Age, styled by survival
sns.scatterplot(data=df, x="fare", y="age", style="survived")

# 4: Age vs Fare, colored by passenger class
sns.scatterplot(data=df, x="age", y="fare", hue="pclass")

# 5: Age vs Fare, with multiple encodings
sns.scatterplot(
    data=df,
    x="age",
    y="fare",
    hue="sex",
    style="survived",
    size="pclass"
)

plt.show()

# ✅ Pie chart example
# Let's say we want to show survival counts as a pie chart
survival_counts = df['survived'].value_counts()
plt.pie(
    survival_counts,
    labels=survival_counts.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Survival Distribution")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.lineplot(data=df, x="pclass", y="fare",
             hue="sex"



             )

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.lineplot(
    data=df,
    x="pclass",
    y="fare",
    marker="o"
)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
plt.figure(figsize=(8,5))

sns.lineplot(
    data=df,
    x="pclass",
    y="fare",
    hue="sex",
    marker="o"
)

plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")

plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv("Titanic1.csv")

sns.lineplot(data=df,
    x="pclass",
             y="age",
             marker="o"
             )
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Titanic1.csv")

plt.figure(figsize=(8,5))

sns.lineplot(
    data=df,
    x="pclass",
    y="fare",
    hue="sex",
    marker="o"
)

plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")

plt.grid(True)

# %% [markdown]
# import pandas as pd
# import numpy as np
# import ma

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv("Titanic1.csv")
sns.relplot(
    data=df,
    x="age",
    y="fare"
)
plt.show()

# %% [markdown]
# # Example 1: Basic Replot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.relplot(
    data=df,
    x="age",
    y="fare"
)

plt.show()import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.relplot(
    data=df,
    x="age",
    y="fare"
)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.relplot(
    data=df,
    x="age",
    y="fare",
    hue="sex"
)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.relplot(
    data=df,
    x="age",
    y="fare",
    hue="sex",
    kind="line"
)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.relplot(
    data=df,
    x="age",
    y="fare",
    hue="sex",
    row="pclass",
)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

# Basic scatterplot with relplot
sns.relplot(
    data=df,
    x="age",
    y="fare",
    kind="scatter",   # must specify kind
    hue="sex",        # optional: color by sex
    style="survived", # optional: marker style by survival
    size="pclass"     # optional: marker size by class
)

plt.show()
