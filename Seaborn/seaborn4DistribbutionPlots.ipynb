# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="sex",
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=False,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=4

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")
plt.figure(figsize=(10,5))

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=3,
    linestyle="--",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=2

)
plt.title("Kernel Density Estimation")
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.histplot(
    data=df,
    x="age",
    kde=True,
)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ****When Should You Use a KDE Plot?
#
# Use a KDE plot when you want to:
#
# Understand the overall shape of your data.
# Compare distributions between groups.
# See where values are concentrated.
# Avoid the blocky appearance of a histogram.
#
# Avoid using KDE when:
#
# Your dataset is very small (the curve may be misleading).
# Your variable is categorical instead of numerical.****

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="fare",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.displot(data=df,x="age")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="sex",
    color="white"
)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=False,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=4

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")
plt.figure(figsize=(10,5))

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=3,
    linestyle="--",

)
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv("Titanic1.csv")

sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    hue="survived",
    linewidth=2

)
plt.title("Kernel Density Estimation")
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Kernel Density Estimation")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.histplot(
    data=df,
    x="age",
    kde=True,
)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ****When Should You Use a KDE Plot?
#
# Use a KDE plot when you want to:
#
# Understand the overall shape of your data.
# Compare distributions between groups.
# See where values are concentrated.
# Avoid the blocky appearance of a histogram.
#
# Avoid using KDE when:
#
# Your dataset is very small (the curve may be misleading).
# Your variable is categorical instead of numerical.****

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="fare",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("Titanic1.csv")
sns.kdeplot(
    data=df,
    x="age",
    fill=True,
    color="red",
    hue="sex",

)
plt.title("Fare distribution")
# Out:
# Text(0.5, 1.0, 'Fare distribution')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Titanic1.csv")

sns.displot(data=df,
            x="age",
            kind="kde",


            )
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.displot(
    data=df,
    x="age",
    kde=True,
    color="blue",
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
sns.displot(
    data=df,
    x="age",
    kde=True,
    color="blue",
    bins=20
)
plt.title("Fare distribution")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Titanic1.csv")
# sns.displot(
#     data=df,
#     x="age",
#     kde=True,
#     color="blue",
#     col="sex"
# )
sns.displot(
    data=df,
    x="age",
    color="green",
    col="sex"
)
plt.title("Fare distribution")

plt.show()
